# %% [markdown]
# **Principle of  Data Visualization**

# %% [markdown]
# What is Data Visualization?

# %% [markdown]
# Data visualization is the graphical representation of data and information using visual elements such as charts, graphs, and maps, allowing for easier understanding and interpretation of complex data sets. By presenting data visually, patterns, trends, and insights can be more easily identified, helping users make more informed decisions and draw meaningful conclusions from the data. Data visualization is an important tool in various fields such as business, science, marketing, and research.

# %% [markdown]
# **Different Plots**

# %% [markdown]
# Bar Graph
#
# Histogram
#
# Pie Chart
#
# Line Chart
#
# Outlires
#
# Scatterd plot

# %% [markdown]
# **Bar Chart**:
# For example
# Helpful in categorical data predection.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Histogram**:
# Use for more over the continuous type of data Like when we have 100 random number over the year or the monthly basic the average age is used to plot through the histogram.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Line chart**:
# For eample: Helpful in temperature Predection

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Pie Chart**:
# For example : we get actual percentage out of the total percentages it complete the data they always take 100%.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Outlires:
# Box Plot

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Scatterd plot

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Power BI:
#  Data Visualization tools launch by microsoft used for data visualization.

# %% [markdown]
# Plotly Library:used for creating very interactive dashboard used in R programming suit for web based.principle of plotly Interactive graphs, Wide range of chart,Customization,crossed Platform Support works with html file web application very easy to install.

# %% [markdown]
# Principle 1-
# Clarity
#
# Avoid Clutter
#
# Use clear visual hierarchies.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Principle 2-
# Accessibility
#
# Use color schemes that are colorblind friendly
#
# Ensure text is redable

# %% [markdown]
# Principle 3 - Accuracy
#
# Use appropriate scales and axes.
#
# Avoid misleading representations.

# %% [markdown]
# Principle 4 - Relevance
#
# Tailor visualizations to audience.
#
# Highlight what's most important.

# %% [markdown]
# Principle 5 - Aesthetics
#
# Balance color and design elements.
#
# Use whitespace effectively.

# %% [markdown]
# Principle 6 - Interaction
#
# Example of interactive tools(e.g, Hover,drill-down).
#
# Benefits of interaction in exploring data.

# %% [markdown]
# Principle 7 - Context
#
# Keep the "Big picture" In mind.
#
# Compare and constrast data point.
